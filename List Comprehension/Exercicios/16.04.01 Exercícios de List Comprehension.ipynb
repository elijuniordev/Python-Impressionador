# %% [markdown]
# # Exercícios
#
# ## 1. Tamanho do Pedido de Compras
#
# Nesse exercício vamos avaliar o estoque de uma empresa. Vamos considerar que todos os produtos dessa empresa são comprados em lotes de 500 unidades.
#
# - Caso o estoque esteja abaixo de 1000 unidades, devemos fazer um pedido de 500 unidades.
# - Caso o estoque esteja abaixo de 200 unidades, devemos fazer um pedido de 1000 unidades.
#
# Defina o valor a ser pedido de cada produto para enviar ao time de compras.

# %%
estoque = [('BSA2199',351),('PPF5239',251),('BSA1212',989),('PPF2154',449),('BEB3410',241),('PPF8999',527),('EMB9591',601),('BSA2006',314),('EMB3604',469),('EMB2070',733),('PPF9018',339),('PPF1468',906),('BSA5819',291),('PPF8666',850),('BEB2983',353),('BEB5877',456),('PPF5008',963),('PPF3877',185),('PPF7321',163),('BSA8833',644),('PPF4980',421),('PPF3063',757),('BSA2089',271),('BSA8398',180),('EMB4622',515),('EMB9814',563),('PPF3784',229),('PPF2398',270),('BEB3211',181),('PPF8655',459),('PPF1874',799),('PPF8789',126),('PPF6324',375),('EMB9290',883),('BSA5516',555),('BSA8451',243),('BSA8213',423)]

for cod, quant in estoque:
    if quant < 1000 and quant > 200:
        print('Realizar um pedido de 500 unidades do produto {}'.format(cod))
    elif quant < 200:
        print('Realizar um pedido de 200 unidades do produto {}'.format(cod))
    else:
        print('Não é necessário fazer pedido do produto {}'.format(cod))

lista_pedidos = []
for produto, quantidade in estoque:
    if quantidade < 200:
        lista_pedidos.append(500)
    else:
        lista_pedidos.append(200)
print(lista_pedidos)
# Out:
# Realizar um pedido de 500 unidades do produto BSA2199
# Realizar um pedido de 500 unidades do produto PPF5239
# Realizar um pedido de 500 unidades do produto BSA1212
# Realizar um pedido de 500 unidades do produto PPF2154
# Realizar um pedido de 500 unidades do produto BEB3410
# Realizar um pedido de 500 unidades do produto PPF8999
# Realizar um pedido de 500 unidades do produto EMB9591
# Realizar um pedido de 500 unidades do produto BSA2006
# Realizar um pedido de 500 unidades do produto EMB3604
# Realizar um pedido de 500 unidades do produto EMB2070
# Realizar um pedido de 500 unidades do produto PPF9018
# Realizar um pedido de 500 unidades do produto PPF1468
# Realizar um pedido de 500 unidades do produto BSA5819
# Realizar um pedido de 500 unidades do produto PPF8666
# Realizar um pedido de 500 unidades do produto BEB2983
# Realizar um pedido de 500 unidades do produto BEB5877
# Realizar um pedido de 500 unidades do produto PPF5008
# Realizar um pedido de 200 unidades do produto PPF3877
# Realizar um pedido de 200 unidades do produto PPF7321
# Realizar um pedido de 500 unidades do produto BSA8833
# Realizar um pedido de 500 unidades do produto PPF4980
# Realizar um pedido de 500 unidades do produto PPF3063
# Realizar um pedido de 500 unidades do produto BSA2089
# Realizar um pedido de 200 unidades do produto BSA8398
# Realizar um pedido de 500 unidades do produto EMB4622
# Realizar um pedido de 500 unidades do produto EMB9814
# Realizar um pedido de 500 unidades do produto PPF3784
# Realizar um pedido de 500 unidades do produto PPF2398
# Realizar um pedido de 200 unidades do produto BEB3211
# Realizar um pedido de 500 unidades do produto PPF8655
# Realizar um pedido de 500 unidades do produto PPF1874
# Realizar um pedido de 200 unidades do produto PPF8789
# Realizar um pedido de 500 unidades do produto PPF6324
# Realizar um pedido de 500 unidades do produto EMB9290
# Realizar um pedido de 500 unidades do produto BSA5516
# Realizar um pedido de 500 unidades do produto BSA8451
# Realizar um pedido de 500 unidades do produto BSA8213
# [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 5000, 5000, 200, 200, 200, 200, 5000, 200, 200, 200, 200, 5000, 200, 200, 5000, 200, 200, 200, 200, 200]

# %%
estoque = [('BSA2199',351),('PPF5239',251),('BSA1212',989),('PPF2154',449),('BEB3410',241),('PPF8999',527),('EMB9591',601),('BSA2006',314),('EMB3604',469),('EMB2070',733),('PPF9018',339),('PPF1468',906),('BSA5819',291),('PPF8666',850),('BEB2983',353),('BEB5877',456),('PPF5008',963),('PPF3877',185),('PPF7321',163),('BSA8833',644),('PPF4980',421),('PPF3063',757),('BSA2089',271),('BSA8398',180),('EMB4622',515),('EMB9814',563),('PPF3784',229),('PPF2398',270),('BEB3211',181),('PPF8655',459),('PPF1874',799),('PPF8789',126),('PPF6324',375),('EMB9290',883),('BSA5516',555),('BSA8451',243),('BSA8213',423)]

#bonus = [vendedores_dic[item] * 0.1 if vendedores_dic[item] > meta else 0 for item in vendedores_dic]
#print(bonus)

lista_estoque2 = []
lista_est2 = [(lista_estoque2.append(1000)) if quant < 200 else (lista_estoque2.append(500)) for cod, quant in estoque]

print(lista_estoque2)
# Out:
# [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 1000, 1000, 500, 500, 500, 500, 1000, 500, 500, 500, 500, 1000, 500, 500, 1000, 500, 500, 500, 500, 500]
